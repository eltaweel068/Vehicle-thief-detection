# %% [markdown]
# <a href="https://colab.research.google.com/github/eltaweel068/Vehicle-thief-detection/blob/main/vehicle_thief_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 68.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 84.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 130.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="mvHmXwWHB7dq5f2A5SRb")
project = rf.workspace("cv-projects-xtgoe").project("vehicle-thief-detection")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to vehicle-thief-detection-3 in yolov8:: 100%|██████████| 676/676 [00:00<00:00, 9492.58it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !yolo train data='vehicle-thief-detection-3/data.yaml' model=yolov8n.pt epochs=25 imgsz=640

# %%
# !ls vehicle-thief-detection-3/test/images
# Out:
# 2fa48060-e77c-11ef-a775-0242ac1c000c_jpg.rf.b04e7a9a779336da830a17623ae370a2.jpg
# 30f2f49c-e77c-11ef-a775-0242ac1c000c_jpg.rf.ff0b300633fdb588feb2aa20f75322a7.jpg
# 362e0c30-e77c-11ef-a775-0242ac1c000c_jpg.rf.362cc243dc16d09e8a62fd0eb5b2ec10.jpg
# 3dc5c2d0-e77c-11ef-a775-0242ac1c000c_jpg.rf.217be0d18beec9cdc1322fed4c2736fb.jpg
# 3df70192-e77c-11ef-a775-0242ac1c000c_jpg.rf.c75c21c27387be792888306102763cc7.jpg
# 40a86ab6-e77c-11ef-a775-0242ac1c000c_jpg.rf.27458611368a48bffb2b7295632a0f98.jpg
# 79a90fa0-e77c-11ef-a775-0242ac1c000c_jpg.rf.216b0da15e639dec80156136abfcc8aa.jpg
# 8e6e8046-e77c-11ef-a775-0242ac1c000c_jpg.rf.9d7406b1ca082e267feab6dcb4444fc2.jpg
# 8e7b898a-e77c-11ef-a775-0242ac1c000c_jpg.rf.21a6d681ce36b5ea5af2c8236671d7cd.jpg
# 906e15fa-e77c-11ef-a775-0242ac1c000c_jpg.rf.ddae00c058a83733d6b9c3b420386f25.jpg
# 967b2d20-e77c-11ef-a775-0242ac1c000c_jpg.rf.6b4ffd6dfc8a3080315db61c7e263c7b.jpg
# 97503894-e77c-11ef-a775-0242ac1c000c_jpg.rf.4a3d2e0b349179c8006746e0182c8e3c.jpg
# ...

# %%
# !ls
# Out:
# drive  runs  sample_data  vehicle-thief-detection-3  yolo11n.pt  yolov8n.pt

# %%
# !yolo predict model='/content/runs/detect/train/weights/best.pt' source='vehicle-thief-detection-3/test/images/30f2f49c-e77c-11ef-a775-0242ac1c000c_jpg.rf.ff0b300633fdb588feb2aa20f75322a7.jpg'
# Out:
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/vehicle-thief-detection-3/test/images/30f2f49c-e77c-11ef-a775-0242ac1c000c_jpg.rf.ff0b300633fdb588feb2aa20f75322a7.jpg: 640x640 1 theft, 8.5ms
# Speed: 2.5ms preprocess, 8.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict5
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !ls -l runs/detect/predict
# Out:
# total 64
# -rw-r--r-- 1 root root 63106 Nov 26 08:29 30f2f49c-e77c-11ef-a775-0242ac1c000c_jpg.rf.ff0b300633fdb588feb2aa20f75322a7.jpg

# %%
# !ls -l runs/detect/predict
# Out:
# total 64
# -rw-r--r-- 1 root root 63106 Nov 26 08:29 30f2f49c-e77c-11ef-a775-0242ac1c000c_jpg.rf.ff0b300633fdb588feb2aa20f75322a7.jpg

# %%
Image(filename='/content/runs/detect/predict/30f2f49c-e77c-11ef-a775-0242ac1c000c_jpg.rf.ff0b300633fdb588feb2aa20f75322a7.jpg')

# %%
# !cp /content/runs/detect/train/weights/best.pt /content/drive/MyDrive/

# %%
# !pip install ultralytics

# %%
# !yolo val model='/content/runs/detect/train/weights/best.pt' data='vehicle-thief-detection-3/data.yaml' split='test'
# Out:
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1841.6±359.8 MB/s, size: 43.3 KB)
# val: Scanning /content/vehicle-thief-detection-3/test/labels.cache... 21 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 21/21 388.0Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.5it/s 0.6s
#                    all         21         21      0.945      0.952       0.98      0.567
# Speed: 4.4ms preprocess, 10.1ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to /content/runs/detect/val3
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo predict model='/content/runs/detect/train/weights/best.pt' source='vehicle-thief-detection-3/test/images/9d5b11dc-e77c-11ef-a775-0242ac1c000c_jpg.rf.194a7e9fbe187a614b8a97b6c0397aa4.jpg' conf=0.5
# Out:
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/vehicle-thief-detection-3/test/images/9d5b11dc-e77c-11ef-a775-0242ac1c000c_jpg.rf.194a7e9fbe187a614b8a97b6c0397aa4.jpg: 640x640 1 theft, 8.8ms
# Speed: 2.2ms preprocess, 8.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict6
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import Image
Image(filename='/content/runs/detect/predict6/9d5b11dc-e77c-11ef-a775-0242ac1c000c_jpg.rf.194a7e9fbe187a614b8a97b6c0397aa4.jpg')

# %% [markdown]
# # Task
# Mount Google Drive, correct the validation command to use `vehicle-thief-detection-3/data.yaml`, download a public domain video for inference, perform YOLOv8 prediction on this video and on images from the local test set located in `/content/vehicle-thief-detection-3/test/images`, and then display the predicted images.

# %% [markdown]
# ## Mount Google Drive
#
# ### Subtask:
# Mount Google Drive to allow saving files to `/content/drive/MyDrive/`, addressing the error in cell `NGSX1WxQuAFi`.

# %% [markdown]
# **Reasoning**:
# Mount Google Drive to allow saving files to `/content/drive/MyDrive/` by importing the `drive` module from `google.colab` and using `drive.mount()`.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Correct Validation Data Path
#
# ### Subtask:
# Ensure the validation command in cell GBgHSlZB3tUo uses the same data.yaml path as the training command (vehicle-thief-detection-3/data.yaml) for consistency.

# %% [markdown]
# **Reasoning**:
# The subtask requires correcting the data path in the `yolo val` command for consistency with the training data path. I will modify the `data` argument in the specified cell.

# %%
# !yolo val model='/content/runs/detect/train/weights/best.pt' data='vehicle-thief-detection-3/data.yaml' split='test'
# Out:
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1455.1±528.2 MB/s, size: 45.2 KB)
# val: Scanning /content/vehicle-thief-detection-3/test/labels... 21 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 21/21 1.8Kit/s 0.0s
# val: New cache created: /content/vehicle-thief-detection-3/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.0it/s 0.5s
#                    all         21         21      0.945      0.952       0.98      0.567
# Speed: 4.8ms preprocess, 6.7ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to /content/runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# ## Download Public Domain Video for Prediction
#
# ### Subtask:
# The previous YouTube video downloads failed due to authentication issues. This step will attempt to download a public domain video that does not require login, allowing for successful video inference in subsequent steps. This will address the errors in cells XAANUNKBaFem, MLkQaS2Dal1l, -oQHupHUasG7, and QbzpA_SdF0vv.

# %% [markdown]
# **Reasoning**:
# The previous attempts to download videos from YouTube failed due to authentication issues. To address this, I will provide a command to download a public domain video using `yt-dlp`. The user needs to manually find a suitable public domain video URL and replace the placeholder in the command to proceed.

# %%
# !yolo predict model='/content/runs/detect/train/weights/best.pt' source='/content/vehicle-thief-detection-3/test/images' conf=0.5
# Out:
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/21 /content/vehicle-thief-detection-3/test/images/2fa48060-e77c-11ef-a775-0242ac1c000c_jpg.rf.b04e7a9a779336da830a17623ae370a2.jpg: 640x640 1 theft, 8.9ms
# image 2/21 /content/vehicle-thief-detection-3/test/images/30f2f49c-e77c-11ef-a775-0242ac1c000c_jpg.rf.ff0b300633fdb588feb2aa20f75322a7.jpg: 640x640 1 theft, 7.3ms
# image 3/21 /content/vehicle-thief-detection-3/test/images/362e0c30-e77c-11ef-a775-0242ac1c000c_jpg.rf.362cc243dc16d09e8a62fd0eb5b2ec10.jpg: 640x640 1 theft, 7.2ms
# image 4/21 /content/vehicle-thief-detection-3/test/images/3dc5c2d0-e77c-11ef-a775-0242ac1c000c_jpg.rf.217be0d18beec9cdc1322fed4c2736fb.jpg: 640x640 1 theft, 7.2ms
# image 5/21 /content/vehicle-thief-detection-3/test/images/3df70192-e77c-11ef-a775-0242ac1c000c_jpg.rf.c75c21c27387be792888306102763cc7.jpg: 640x640 1 theft, 7.2ms
# ...

# %% [markdown]
# ## Display Predicted Images from Test Set
#
# ### Subtask:
# Display some of the predicted images from the test set, located in `/content/runs/detect/predict2`, to visually inspect the YOLOv8 model's performance.

# %% [markdown]
# ## Display Predicted Images from Test Set
#
# ### Subtask:
# Display some of the predicted images from the test set, located in `/content/runs/detect/predict2`, to visually inspect the YOLOv8 model's performance.

# %% [markdown]
# **Reasoning**:
# To display the predicted images, I first need to list the contents of the `/content/runs/detect/predict2` directory to identify the filenames that were generated by the YOLOv8 prediction.

# %%
from IPython.display import Image
# !ls /content/runs/detect/predict2
# Out:
# 2fa48060-e77c-11ef-a775-0242ac1c000c_jpg.rf.b04e7a9a779336da830a17623ae370a2.jpg
# 30f2f49c-e77c-11ef-a775-0242ac1c000c_jpg.rf.ff0b300633fdb588feb2aa20f75322a7.jpg
# 362e0c30-e77c-11ef-a775-0242ac1c000c_jpg.rf.362cc243dc16d09e8a62fd0eb5b2ec10.jpg
# 3dc5c2d0-e77c-11ef-a775-0242ac1c000c_jpg.rf.217be0d18beec9cdc1322fed4c2736fb.jpg
# 3df70192-e77c-11ef-a775-0242ac1c000c_jpg.rf.c75c21c27387be792888306102763cc7.jpg
# 40a86ab6-e77c-11ef-a775-0242ac1c000c_jpg.rf.27458611368a48bffb2b7295632a0f98.jpg
# 79a90fa0-e77c-11ef-a775-0242ac1c000c_jpg.rf.216b0da15e639dec80156136abfcc8aa.jpg
# 8e6e8046-e77c-11ef-a775-0242ac1c000c_jpg.rf.9d7406b1ca082e267feab6dcb4444fc2.jpg
# 8e7b898a-e77c-11ef-a775-0242ac1c000c_jpg.rf.21a6d681ce36b5ea5af2c8236671d7cd.jpg
# 906e15fa-e77c-11ef-a775-0242ac1c000c_jpg.rf.ddae00c058a83733d6b9c3b420386f25.jpg
# 967b2d20-e77c-11ef-a775-0242ac1c000c_jpg.rf.6b4ffd6dfc8a3080315db61c7e263c7b.jpg
# 97503894-e77c-11ef-a775-0242ac1c000c_jpg.rf.4a3d2e0b349179c8006746e0182c8e3c.jpg
# ...

# %% [markdown]
# **Reasoning**:
# Based on the output of the previous `!ls` command, I will now display a few of the predicted images from the `/content/runs/detect/predict2` directory to visually inspect the model's performance.

# %%
from IPython.display import Image

Image(filename='/content/runs/detect/predict2/2fa48060-e77c-11ef-a775-0242ac1c000c_jpg.rf.b04e7a9a779336da830a17623ae370a2.jpg')

# %% [markdown]
# **Reasoning**:
# I have displayed one predicted image. To further visually inspect the model's performance as requested by the subtask, I will display another predicted image from the `/content/runs/detect/predict2` directory.

# %%
from IPython.display import Image

Image(filename='/content/runs/detect/predict2/79a90fa0-e77c-11ef-a775-0242ac1c000c_jpg.rf.216b0da15e639dec80156136abfcc8aa.jpg')
